# %%
# %load_ext autoreload
# %autoreload

# %%
# Zoznam datasetov, ktore su dostupne v datovom v repozitari

datasetDict = {
    "exp1": {"dataRepoPath": "../dataRepo/", "dataFile_main": "exp1.csv"},
    "exp2": {"dataRepoPath": "../dataRepo/", "dataFile_main": "exp2.csv"},
    "exp3": {"dataRepoPath": "../dataRepo/", "dataFile_main": "exp3.csv"},
    "exp4": {"dataRepoPath": "../dataRepo/", "dataFile_main": "exp4.csv"},
    "exp5": {"dataRepoPath": "../dataRepo/", "dataFile_main": "exp5.csv"},
}

# %%
# Jednoducha vizualizacia dat

for data_pot in datasetDict.keys():

    figName = 'fj_01_' + data_pot
    
    exec(open('./figjobs/figJob_01.py', encoding='utf-8').read())
