# %%
# %load_ext autoreload
# %autoreload

# %%
# Zoznam datasetov, ktore su dostupne v datovom v repozitari

datasetDict = {

    'data_pot0': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot0_logsout.csv',
        'dataFile_inputTable': 'data_pot0_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot1': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot1_logsout.csv',
        'dataFile_inputTable': 'data_pot1_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot2': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot2_logsout.csv',
        'dataFile_inputTable': 'data_pot2_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot3': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot3_logsout.csv',
        'dataFile_inputTable': 'data_pot3_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot4': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot4_logsout.csv',
        'dataFile_inputTable': 'data_pot4_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot5': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot5_logsout.csv',
        'dataFile_inputTable': 'data_pot5_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot6': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot6_logsout.csv',
        'dataFile_inputTable': 'data_pot6_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot7': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot7_logsout.csv',
        'dataFile_inputTable': 'data_pot7_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot8': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot8_logsout.csv',
        'dataFile_inputTable': 'data_pot8_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot9': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot9_logsout.csv',
        'dataFile_inputTable': 'data_pot9_inputTable.csv',
        'steadyDurationPercent' : 30,
    },

    'data_pot10': {
        'dataRepoPath': '../ML/dataRepo/dataSet01/',
        'dataFile_main': 'data_pot10_logsout.csv',
        'dataFile_inputTable': 'data_pot10_inputTable.csv',
        'steadyDurationPercent' : 30,
    }, 

}

# %%
# Jednoducha vizualizacia dat

for data_pot in datasetDict.keys():

    figName = 'fj_01_' + data_pot
    
    exec(open('./figjobs/figJob_01.py', encoding='utf-8').read())

# %%
# Vytvorenie dat, ktore obsahuju useky kde je system v ustalenom stave

for data_pot in datasetDict.keys():    

    exec(open('./datajobs/dataJob_02.py', encoding='utf-8').read())

# %%
# Spracovanie dát pre prevádzkovú podmienku 0 [V]

data_pot = 'data_pot0' # Oznacenie pre prevadzkovu podmienku 0 [V]


# ----------------------------------------------
# Vykreslenie ustalenych usekov

exec(open('./figjobs/figJob_02.py', encoding='utf-8').read()) # skript je v subore figJob_02.py


# ----------------------------------------------
# Zlucenie usekov do datasetu ustalenych stavov

dataRepoDir = './dataRepo/'

sch_files = [
    f for f in os.listdir(dataRepoDir)
    if f.startswith('SCH') and data_pot in f
]

steadyStateData = np.empty((0, 2))

for sch_file in sch_files:

    sch_data = np.loadtxt(
        dataRepoDir + sch_file,
        delimiter=',',
        skiprows=1,  
    )

    steadyStateData = np.vstack([steadyStateData, sch_data[:, 1:3]])

np.savetxt(dataRepoDir + 'ALLSCH_' + data_pot + '_steadyStateData' + '.csv',
    steadyStateData,
    delimiter=',',
    fmt='%.3f',
    header='sigOut,sigIn',
    comments='',
)


# ----------------------------------------------
# Vykreslenie dat ustalenych stavov

exec(open('./figjobs/figJob_03.py', encoding='utf-8').read())

# ----------------------------------------------
# Identifikacia modelu na linearnom useku

tmpMask = (steadyStateData[:, 1] >= 0) & (steadyStateData[:, 1] <= 7.1)

identData = steadyStateData[tmpMask, :]

polyKoef = np.polyfit(
    identData[:, 1],
    identData[:, 0],
    deg=1
)

print('Identifikovane koeficienty: ', polyKoef)

# plot data pre f_1
plot_u1 = np.arange(0, 7.1, 0.1)        
plot_y1 = np.polyval(polyKoef, plot_u1)

# plot data pre f_2
plot_u2 = np.arange(7, 10.1, 0.1)
plot_y2 = 10 * np.ones_like(plot_u2)

exec(open('./figjobs/figJob_04.py', encoding='utf-8').read())
# Out:
# Identifikovane koeficienty:  [ 1.39905969 -0.11960579]

# %%
# Jednoducha vizualizacia dat

# figSaveDir = './fig/'


# for data_pot in datasetDict.keys():


#     data_main = np.loadtxt(
#         datasetDict[data_pot]['dataRepoPath'] + datasetDict[data_pot]['dataFile_main'], 
#         delimiter=',', 
#     )

#     data_inputTable = np.loadtxt(
#         datasetDict[data_pot]['dataRepoPath'] + datasetDict[data_pot]['dataFile_inputTable'], 
#         delimiter=',', 
#     )

#     figName = 'fj_01_' + data_pot 

#     exec(open('./figjobs/figJob_01.py', encoding='utf-8').read())

# %%
# figName

# %%
# import os

# figSaveDir = './fig/'

# dataRepoDir = './dataRepo/'

# data_pot = 'data_pot0'


# -----------------------



# data_main = np.loadtxt(
#     datasetDict[data_pot]['dataRepoPath'] + datasetDict[data_pot]['dataFile_main'], 
#     delimiter=',', 
# )

# data_inputTable = np.loadtxt(
#     datasetDict[data_pot]['dataRepoPath'] + datasetDict[data_pot]['dataFile_inputTable'], 
#     delimiter=',', 
# )



# sch_files = [
#     f for f in os.listdir(dataRepoDir)
#     if f.startswith('SCH') and data_pot in f
# ]

# for fname in sch_files:
#     print(fname)


# exec(open('./figjobs/figJob_02.py', encoding='utf-8').read())

# %%
# plt.figure(1)

# plt.subplot(3, 1, 1)
# plt.plot(
#     data_main[:, 0], data_main[:, 1], 
#     'k',
#     lw=0.5,
#     label='tacho',
# )
# plt.title('tacho')

# plt.subplot(3, 1, 2)
# plt.plot(
#     data_main[:, 0], data_main[:, 3], 
#     'k',
#     lw=0.5,
#     label='input'
# )
# plt.title('input')

# plt.subplot(3, 1, 3)
# plt.plot(
#     data_main[:, 0], data_main[:, 2], 
#     'k',
#     lw=0.5,
#     label='potentiometer'
# )
# plt.title('potentiometer')





# steadyStateChar = np.zeros((len(data_inputTable[:,0]), 2))



# for tmpidx in range(0,len(data_inputTable[:,0])):



#     stairTime_start = data_inputTable[tmpidx,0]

#     if tmpidx < len(data_inputTable[:,0])-1:
#         stairTime_stop = data_inputTable[tmpidx+1,0]
#     else:
#         stairTime_stop = data_main[-1,0]

#     steadyTime_start = stairTime_start + (stairTime_stop-stairTime_start)*(100-steadyDuration)/100

#     tmp_mask = (data_main[:,0] >= steadyTime_start) & (data_main[:,0] < stairTime_stop)

#     tmp_time = data_main[tmp_mask,0]
#     tmp_sigOut = data_main[tmp_mask,1]
#     tmp_sigIn = data_main[tmp_mask,3]

#     steadyStateChar[tmpidx,0] = np.mean(tmp_sigIn)
#     steadyStateChar[tmpidx,1] = np.mean(tmp_sigOut)


#     plt.figure(1)

#     plt.subplot(3, 1, 1)
#     plt.plot(
#         tmp_time, tmp_sigOut, 
#         'r',
#     )

#     plt.subplot(3, 1, 2)
#     plt.plot(
#         tmp_time, tmp_sigIn, 
#         'r',
#     )

#     plt.figure(2)
#     plt.plot(
#         tmp_sigIn, tmp_sigOut,
#         'k',
#         lw=0,
#         marker='.',
#         markersize=8,
#         mew=0,
#         markerfacecolor=(0, 0, 0, 0.01),
#     )


#     plt.figure(3)
#     plt.plot(
#         tmp_time - tmp_time[0],
#         tmp_sigOut - np.mean(tmp_sigOut),
#         lw=0.8,
#         label='in {:.1f}'.format(np.mean(tmp_sigIn)),
#     )
#     plt.title('Graphical Comparison of Steady State Data')
#     plt.legend()




    
# plt.figure(1)
# plt.tight_layout()
# plt.show()



# plt.figure(2)

# plt.plot(
#     steadyStateChar[:,0], steadyStateChar[:,1],
#     'r',
#     lw=0,
#     marker='+',
#     markersize=10,
# )

# plt.tight_layout()
# plt.show()



# plt.figure(3)
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(10)

# plt.plot(
#     steadyStateChar[:,0], steadyStateChar[:,1],
#     'r',
#     lw=0,
#     marker='+',
#     markersize=10,
# )


# plt.tight_layout()
# plt.show()




# # Custom find a lienar part of steadyStateChar

# steadyStateCharDiff = np.diff(steadyStateChar[:,1], n=1, prepend=steadyStateChar[0,1], append=steadyStateChar[-1,1])

# tmp_mask = np.abs(steadyStateCharDiff[1:]) > (( np.abs(steadyStateCharDiff[1]) + np.abs(steadyStateCharDiff[-2]))/2)

# last_true_index = np.where(tmp_mask)[0][-1]


# tmp_mask[last_true_index+1] = True


# tmp_polyfitcoef = np.polyfit(steadyStateChar[:,0][tmp_mask], steadyStateChar[:,1][tmp_mask], 1)

# plt.plot(
#     steadyStateChar[tmp_mask,0],
#     np.polyval(tmp_polyfitcoef, steadyStateChar[tmp_mask,0]),
#     'k',
#     lw=0.5,
# )

# print(steadyStateCharDiff[1:-1])
